# %% [markdown]
# # Prueba de la API — Predicción de cancelaciones hoteleras
#
# Notebook para consumir la API desplegada en Render.
# Con la URL que nos proporciona Render ya podemos consumir la API desde cualquier sitio. Sustituye `BASE_URL` por la URL real de tu servicio.

# %%
import requests

BASE_URL = 'https://tc-m-03-despliegue-modelo.onrender.com'

# %% [markdown]
# ---
# ## Endpoint 1 - Landing page `/`
# Muestra todos los endpoints disponibles y cómo usarlos.

# %%
response = requests.get(BASE_URL + '/')
print(response.status_code)
print(response.text)
# Out:
# 200
# {"ejemplo_uso":"/predict?hotel=Resort%20Hotel&customer_type=Transient&market_segment=Online%20TA&deposit_type=No%20Deposit&meal=BB&country=PRT&distribution_channel=TA/TO&reserved_room_type=A&is_repeated_guest=0&lead_time=120&previous_cancellations=0&adults=2&days_in_waiting_list=0&adr=95.5&previous_bookings_not_canceled=0&booking_changes=1&required_car_parking_spaces=0&total_of_special_requests=1","endpoint_prediccion":"/predict","mensaje":"API de predicci\u00f3n de cancelaciones hoteleras","metodo":"GET","modelo":"Random Forest optimizado","variables_esperadas":["hotel","customer_type","market_segment","deposit_type","meal","country","distribution_channel","reserved_room_type","is_repeated_guest","lead_time","previous_cancellations","adults","days_in_waiting_list","adr","previous_bookings_not_canceled","booking_changes","required_car_parking_spaces","total_of_special_requests"]}

# %% [markdown]
# ---
# ## Endpoint 2 — Predicción `/predict`
# Los parámetros se pasan como **query string** (`params=...`).
# El modelo devuelve la predicción (0/1), la etiqueta y las probabilidades de cada clase.
#
# | Parámetro | Tipo | Valores |
# |---|---|---|
# | hotel | str | Resort Hotel \| City Hotel |
# | customer_type | str | Transient \| Contract \| Group \| Transient-Party |
# | market_segment | str | Online TA \| Offline TA/TO \| Direct \| Corporate \| ... |
# | deposit_type | str | No Deposit \| Non Refund \| Refundable |
# | meal | str | BB \| HB \| FB \| SC \| Undefined |
# | country | str | Código ISO-3166 (PRT, ESP, GBR, USA...) |
# | distribution_channel | str | TA/TO \| Direct \| Corporate \| GDS \| Undefined |
# | reserved_room_type | str | A \| B \| C \| D \| E \| F \| G \| H \| L |
# | is_repeated_guest | int | 0 = cliente nuevo \| 1 = repetido |
# | lead_time | int | días de antelación |
# | previous_cancellations | int | cancelaciones previas |
# | adults | int | número de adultos |
# | days_in_waiting_list | int | días en lista de espera |
# | adr | float | precio medio diario |
# | previous_bookings_not_canceled | int | reservas previas no canceladas |
# | booking_changes | int | cambios en la reserva |
# | required_car_parking_spaces | int | plazas de parking |
# | total_of_special_requests | int | peticiones especiales |

# %%
# Reserva 1: perfil de BAJO riesgo de cancelación
# Cliente repetido, sin cancelaciones previas, poca antelación, depósito no reembolsable
params = {
    'hotel':                          'Resort Hotel',
    'customer_type':                  'Transient',
    'market_segment':                 'Direct',
    'deposit_type':                   'Non Refund',
    'meal':                           'BB',
    'country':                        'PRT',
    'distribution_channel':           'Direct',
    'reserved_room_type':             'A',
    'is_repeated_guest':              1,
    'lead_time':                      10,
    'previous_cancellations':         0,
    'adults':                         2,
    'days_in_waiting_list':           0,
    'adr':                            90,
    'previous_bookings_not_canceled': 5,
    'booking_changes':                0,
    'required_car_parking_spaces':    1,
    'total_of_special_requests':      2,
}
response = requests.get(BASE_URL + '/predict', params=params)
print(response.status_code)
print(response.json())
# Out:
# 200
# {'model': 'Random Forest optimizado', 'prediction': 0, 'prediction_label': 'No cancelada', 'probability_cancelation': 0.366}

# %%
# Reserva 2: perfil de ALTO riesgo de cancelación
# Sin depósito, mucha antelación, historial de cancelaciones, sin peticiones especiales
params = {
    'hotel':                          'City Hotel',
    'customer_type':                  'Transient',
    'market_segment':                 'Online TA',
    'deposit_type':                   'No Deposit',
    'meal':                           'SC',
    'country':                        'GBR',
    'distribution_channel':           'TA/TO',
    'reserved_room_type':             'D',
    'is_repeated_guest':              0,
    'lead_time':                      300,
    'previous_cancellations':         3,
    'adults':                         2,
    'days_in_waiting_list':           0,
    'adr':                            65,
    'previous_bookings_not_canceled': 0,
    'booking_changes':                0,
    'required_car_parking_spaces':    0,
    'total_of_special_requests':      0,
}
response = requests.get(BASE_URL + '/predict', params=params)
print(response.status_code)
print(response.json())
# Out:
# 200
# {'model': 'Random Forest optimizado', 'prediction': 1, 'prediction_label': 'Cancelada', 'probability_cancelation': 0.9636}

# %%
# Reserva 3: con valores faltantes — la API imputa y avisa
params = {
    'hotel':            'City Hotel',
    'customer_type':    'Transient',
    'market_segment':   'Online TA',
    'deposit_type':     'No Deposit',
    'meal':             'BB',
    'country':          'ESP',
    # lead_time, adr y otros campos no se envían
}
response = requests.get(BASE_URL + '/predict', params=params)
print(response.status_code)
print(response.json())
# Out:
# 400
# {'error': "int() argument must be a string, a bytes-like object or a real number, not 'NoneType'"}

# %% [markdown]
# ---
# ## Endpoint 2 — Info del modelo `/health`
#
# > **Nota para la exposición:** este endpoint está comentado en `app.py`.
# > Para activarlo en vivo durante la demo:
# > 1. Descomenta las líneas en `app.py`
# > 2. En bash: `git add app.py && git commit -m "add health endpoint" && git push origin main`
# > 3. Render redespliega automáticamente (~1-2 min)
# > 4. Ejecuta la celda de abajo

# %%
# Ejecutar tras el redespliegue en la exposición
response = requests.get(BASE_URL + '/health')
print(response.status_code)
print(response.json())
# Out:
# 404
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\PC\Desktop\ds_bootcamp\TC-M-03-DESPLIEGUE-MODELO\.venv\Lib\site-packages\requests\models.py:978, in Response.json(self, **kwargs)
#     977 try:
# --> 978     return complexjson.loads(self.text, **kwargs)
#     979 except JSONDecodeError as e:
#     980     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     981     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\AppData\Local\Python\pythoncore-3.13-64\Lib\json\__init__.py:352, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     349 if (cls is None and object_hook is None and
#     350         parse_int is None and parse_float is None and
#     351         parse_constant is None and object_pairs_hook is None and not kw):
# --> 352     return _default_decoder.decode(s)
#     353 if cls is None:
#
# File ~\AppData\Local\Python\pythoncore-3.13-64\Lib\json\decoder.py:345, in JSONDecoder.decode(self, s, _w)
#     341 """Return the Python representation of ``s`` (a ``str`` instance
#     342 containing a JSON document).
#     343
#     344 """
# --> 345 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     346 end = _w(s, end).end()
#
# File ~\AppData\Local\Python\pythoncore-3.13-64\Lib\json\decoder.py:363, in JSONDecoder.raw_decode(self, s, idx)
#     362 except StopIteration as err:
# --> 363     raise JSONDecodeError("Expecting value", s, err.value) from None
#     364 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[9], line 4
#       1 # Ejecutar tras el redespliegue en la exposición
#       2 response = requests.get(BASE_URL + '/health')
#       3 print(response.status_code)
# ----> 4 print(response.json())
#
# File c:\Users\PC\Desktop\ds_bootcamp\TC-M-03-DESPLIEGUE-MODELO\.venv\Lib\site-packages\requests\models.py:982, in Response.json(self, **kwargs)
#     978     return complexjson.loads(self.text, **kwargs)
#     979 except JSONDecodeError as e:
#     980     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     981     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 982     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# ### **¡Enhorabuena!** Has desplegado tu API de manera remota en Render :)
